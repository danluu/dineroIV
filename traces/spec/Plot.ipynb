# %%
# %matplotlib inline
from pandas import read_csv
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
f = open("sandy-2.csv",'r')

# %%
df = read_csv(f)

# %%
import seaborn as sns
sns.set_context("paper")
plt.figure(figsize=(16, 12))

# %%
g = sns.factorplot("name", "miss", "policy", dodge=.2, linestyles=["none", "none", "none", "none"], data=df[df["level"] == 1], size=6)
g.set_xticklabels(rotation=30)

# %%
g = sns.factorplot("name", "miss", "policy", dodge=.2, linestyles=["none", "none", "none", "none"], data=df[df["level"] == 2], size=6)
g.set_xticklabels(rotation=30)

# %%
g = sns.factorplot("name", "miss", "policy", dodge=.2, linestyles=["none", "none", "none", "none"], data=df[df["level"] == 3], size=6)
g.set_xticklabels(rotation=30)

# %%
g = sns.factorplot("name", "miss_ratio", "policy", dodge=.2, linestyles=["none", "none", "none", "none"], data=df[df["level"] == 3], size=6)
g.set_xticklabels(rotation=30)

# %%
f_size = open("size-ratio-means.csv",'r')
dfs = read_csv(f_size)

# %%
g = sns.factorplot("size", "miss_ratio", "policy", dodge=.2, data=dfs, size=6)

# %%
f_size8 = open("sizes-8.csv",'r')
df8 = read_csv(f_size8)

# %%
g = sns.factorplot("size", "miss", "policy", linestyles=["none", "none", "none", "none"], data=df8[df8["size"]==16], size=10)

# %%
g = sns.factorplot("size", "miss", "policy", kind="box", data=df8, size=10)

# %%
df8[df8["size"]==16]
# Out:
#              name policy  size  level      miss
# 0        164.gzip      2    16      1  0.022638
# 10       164.gzip      f    16      1  0.023138
# 20       164.gzip      l    16      1  0.022261
# 30       164.gzip      r    16      1  0.023584
# 40    168.wupwise      2    16      1  0.013833
# 50    168.wupwise      f    16      1  0.014013
# 60    168.wupwise      l    16      1  0.013668
# 70    168.wupwise      r    16      1  0.014887
# 80       171.swim      2    16      1  0.085314
# 90       171.swim      f    16      1  0.086804
# 100      171.swim      l    16      1  0.086764
# 110      171.swim      r    16      1  0.084381
# 120     172.mgrid      2    16      1  0.034622
# 130     172.mgrid      f    16      1  0.034638
# 140     172.mgrid      l    16      1  0.034484
# 150     172.mgrid      r    16      1  0.037515
# 160     173.applu      2    16      1  0.055869
# 170     173.applu      f    16      1  0.055686
# 180     173.applu      l    16      1  0.055102
# ...
